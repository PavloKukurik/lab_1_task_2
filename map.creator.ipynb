# %%
import folium
from haversine import haversine
from geopy.geocoders import Nominatim
from location_reader import find_location
import re

def find_location(path: str) -> list:
    """
    The function find location from file
    :param path: path to file
    :return: name of location
    >>> find_location('film_loc')[:40]

    """
    # with open(path, 'r') as file:
    #     data = file.read()
    # return re.findall(r'[A-Z][a-z]+(?:\s[A-Z][a-z]+)*(?:,\s[A-Za-z]+){2}', data)
    # ----------------------
    list_of_location = []
    with open(path, 'r', encoding='latin-1') as f:
        for line in f:
            if line.startswith('"'):
                parts = line.split('\t')
                title_and_year = re.sub(r'\{.*?\}', '', parts[0].replace('#', '').replace('"', ''))
                location = parts[-1].strip()
                title = title_and_year.split('(')[0].strip()
                year = title_and_year.split('(')[-1].strip(')').strip()
                location_data = [title, year.replace(')', ''), location]
                list_of_location.append(location_data)
    return list_of_location


def take_coordinate(list_of_information: list) -> list:
    """
    The function find coordinate by location
    :param list_of_information: list with all needed information
    :return: coordinate
    # >>> (take_coordinate(find_location('locations.list')[:100]))
    # >>> take_coordinate(find_location('film_loc')[:100])
    """
    result = []
    for i in list_of_information:
        geolocator = Nominatim(user_agent="my_app_name", timeout=100)
        try:
            location = geolocator.geocode(i[2], timeout=100)
            result += [[i[0]] + [i[1]] + [location.latitude] + [location.longitude]]
        except AttributeError:
            continue
    return result


def filter_by_year(list_of_information: list, year: int) -> list:
    """
    The function filter list by year
    :param list_of_information: list
    :param year: year
    :return: filtered list
    # >>> filter_by_year(take_coordinate(find_location('locations.list')[:100]), 2014)
    # >>> filter_by_year(take_coordinate(find_location('film_loc')[:100]), 2014)
    """
    return list(filter(lambda x: int(x[1]) == year, list_of_information))

list_of_filtered_location = filter_by_year(take_coordinate(find_location('locations.list')[:100]), 2016)
m = folium.Map(location=[49.8397, 24.0297], zoom_start=5)
counter = 0
for i in list_of_filtered_location:
    try:
        folium.Marker(location=[i[2], i[3]], popup=f'Name of film: {i[0]}\nYear: {i[1]}\n Distance: {round(haversine((49.8397, 24.0297), (i[2], i[3])), 2)}km', icon=folium.Icon(color='maroon')).add_to(m)
        counter += 1
    except IndexError:
        continue
    if counter > 10:
        break
folium.WmsTileLayer(
    url='http://mesonet.agron.iastate.edu/cgi-bin/wms/nexrad/n0r.cgi',
    name='test',
    fmt='image/png',
    layers='nexrad-n0r-900913',
    transparent=True,
).add_to(m)

m
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12544\3581881605.py:68: UserWarning: color argument of Icon should be one of: {'lightgreen', 'pink', 'green', 'darkpurple', 'darkred', 'lightblue', 'lightgray', 'orange', 'purple', 'lightred', 'black', 'red', 'beige', 'darkgreen', 'gray', 'blue', 'white', 'cadetblue', 'darkblue'}.
#   folium.Marker(location=[i[2], i[3]], popup=f'Name of film: {i[0]}\nYear: {i[1]}\n Distance: {round(haversine((49.8397, 24.0297), (i[2], i[3])), 2)}km', icon=folium.Icon(color='maroon')).add_to(m)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed1f3bff41f342fe92d181d80f694a4b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed1f3bff41f342fe92d181d80f694a4b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed1f3bff41f342fe92d181d80f694a4b = L.map(
#                 &quot;map_ed1f3bff41f342fe92d181d80f694a4b&quot;,
#                 {
#                     center: [49.8397, 24.0297],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_703cf9c4284ee71fcca2b5913dfeade1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ed1f3bff41f342fe92d181d80f694a4b);
#
#
#             var marker_b2006bcfe8abb9200697c1ed35561343 = L.marker(
#                 [40.7127281, -74.0060152],
#                 {}
#             ).addTo(map_ed1f3bff41f342fe92d181d80f694a4b);
#
#
#             var icon_ca0d6d98e028b9e7e6731e2e6d0fdab2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;maroon&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b2006bcfe8abb9200697c1ed35561343.setIcon(icon_ca0d6d98e028b9e7e6731e2e6d0fdab2);
#
#
#         var popup_7ebc76080f3e72a87134be88e94e4ad7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_de31e7b1b93bc01cd2427124f0ab2b4b = $(`&lt;div id=&quot;html_de31e7b1b93bc01cd2427124f0ab2b4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name of film: ActorsLife Year: 2016  Distance: 7174.6km&lt;/div&gt;`)[0];
#                 popup_7ebc76080f3e72a87134be88e94e4ad7.setContent(html_de31e7b1b93bc01cd2427124f0ab2b4b);
#
#
#
#         marker_b2006bcfe8abb9200697c1ed35561343.bindPopup(popup_7ebc76080f3e72a87134be88e94e4ad7)
#         ;
#
#
#
#
#             var marker_22323ff275dfdbbfbab8cd972de75681 = L.marker(
#                 [39.2138905, -79.6371124],
#                 {}
#             ).addTo(map_ed1f3bff41f342fe92d181d80f694a4b);
#
#
#             var icon_453dfeaa84f1e263c5f8b5436d349280 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;maroon&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_22323ff275dfdbbfbab8cd972de75681.setIcon(icon_453dfeaa84f1e263c5f8b5436d349280);
#
#
#         var popup_0e79bbb770324c9ee558137a368672e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_569618c7598cbd266f32cb23d1d01d54 = $(`&lt;div id=&quot;html_569618c7598cbd266f32cb23d1d01d54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name of film: Fuga Year: 2016  Distance: 7626.43km&lt;/div&gt;`)[0];
#                 popup_0e79bbb770324c9ee558137a368672e0.setContent(html_569618c7598cbd266f32cb23d1d01d54);
#
#
#
#         marker_22323ff275dfdbbfbab8cd972de75681.bindPopup(popup_0e79bbb770324c9ee558137a368672e0)
#         ;
#
#
#
#
#             var marker_282f4817846b4f5b599d5196e5c9f6ab = L.marker(
#                 [28.4753569, -81.4671768],
#                 {}
#             ).addTo(map_ed1f3bff41f342fe92d181d80f694a4b);
#
#
#             var icon_b815a88adfd74874c8371eb7999b5617 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;maroon&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_282f4817846b4f5b599d5196e5c9f6ab.setIcon(icon_b815a88adfd74874c8371eb7999b5617);
#
#
#         var popup_da0cc64ec4e5e2878e3bcf0c7f0aabbe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cb8a71e8cf09e129f288c0943699d0e5 = $(`&lt;div id=&quot;html_cb8a71e8cf09e129f288c0943699d0e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name of film: LoveMyRoomie Year: 2016  Distance: 8640.66km&lt;/div&gt;`)[0];
#                 popup_da0cc64ec4e5e2878e3bcf0c7f0aabbe.setContent(html_cb8a71e8cf09e129f288c0943699d0e5);
#
#
#
#         marker_282f4817846b4f5b599d5196e5c9f6ab.bindPopup(popup_da0cc64ec4e5e2878e3bcf0c7f0aabbe)
#         ;
#
#
#
#
#             var marker_8179b83cf124d3f3af4d6e2be8d42440 = L.marker(
#                 [40.6526006, -73.9497211],
#                 {}
#             ).addTo(map_ed1f3bff41f342fe92d181d80f694a4b);
#
#
#             var icon_07feddbc4bc5aad
